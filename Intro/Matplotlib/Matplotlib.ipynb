# %%
import matplotlib.pyplot as plt
# %matplotlib inline
import numpy as np
import pandas as pd
# %reload_ext autoreload
# %autoreload 2

# %%
#simple plot
X = np.linspace(0,5,10)
print(f"X:\n{X}")
Y = X**2
plt.plot(X,Y)
plt.title("Squared Chart")
plt.xlabel("X")
plt.ylabel("y")
# Out:
# X:
# [0.         0.55555556 1.11111111 1.66666667 2.22222222 2.77777778
#  3.33333333 3.88888889 4.44444444 5.        ]
# Text(0, 0.5, 'y')

# %%
#subplot and colors
plt.subplot(1,2,1)
plt.plot(X,Y,"r")
plt.title("First Squared Chart")
plt.subplot(1,2,2)
plt.plot(X,Y,"blue")
plt.title("Scond Squared Chart")
# Out:
# Text(0.5, 1.0, 'Scond Squared Chart')

# %%
#figure and plot lable
plotFigure = plt.figure(figsize=(5,5))
axes = plotFigure.add_axes([1,1,1,1])
axes.set_title("Inverse function")
#lable on the plot
axes.plot(X,Y,"black",label = "X-X^2")
axes.plot(Y,X,"r",label = "X^2-X")
axes.legend(loc=0) # locating lable

# %%
fig , axeses = plt.subplots(figsize = (8,4) , ncols = 3 , nrows = 1)
#seperat plots
plt.tight_layout()
#plots with index
axeses[0].set_title("First Plot")
axeses[0].plot(X,Y,"black")
axeses[1].set_title("Second Plot")
axeses[1].plot(X,Y*X,"red")
axeses[2].set_title("third Plot")
axeses[2].plot(X,X,"green")

# %% [markdown]
# # plt pie

# %%
label = ['Django' , 'Asp .Net' , 'GO lang' , 'Spring MVC']
attenders_count = [120 , 75 , 100,50]
colors_arr = ['r' , 'blue' , 'cyan' , 'green']
plt.pie(attenders_count , labels = label , colors = colors_arr);

# %%
plt.pie(attenders_count , labels = label , colors = colors_arr , autopct = '%1.1f%%');

# %%
plt.pie(attenders_count , labels = label , colors = colors_arr , autopct = '%1.1f%%' , explode = (0.05,0.05,0.05,0.05));

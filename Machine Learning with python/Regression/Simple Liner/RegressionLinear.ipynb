# %%
from sklearn.linear_model import LinearRegression

# %%
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

# %% [markdown]
# Lets Make Our data

# %%
x = np.array([1,2,3]).reshape(-1,1)
y = np.array([3,5,7]).reshape(-1,1)

# %%
plt.plot(x,y)
plt.title("Train Data")
plt.xlabel("X")
plt.ylabel("Y");

# %% [markdown]
# # Lets Make Our Model

# %%
model = LinearRegression()
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.intercept_
# Out:
# array([1.])

# %%
model.coef_
# Out:
# array([[2.]])

# %% [markdown]
# # y = 2x +1

# %%
xtest = np.array([0,2,4]).reshape(-1,1)

# %%
ypredicted = model.predict(xtest)
ypredicted
# Out:
# array([[1.],
#        [5.],
#        [9.]])

# %%
plt.plot(xtest,ypredicted)
plt.plot(xtest,ypredicted,'r.')
plt.title("Test Data")
plt.xlabel("X")
plt.ylabel("Y");
